# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt

# %%
path = ("../data/Social_Network_Ads.csv")
df = pd.read_csv(path)
df
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
def analyzer(max_depth):
    data = pd.read_csv(path)
    X = data.iloc[:,2:4].values
    y = data.iloc[:,-1].values
    clf = DecisionTreeClassifier(max_depth = max_depth)
    a = np.arange(start=X[:,0].min()-1, stop=X[:,0].max()+1,step=0.1)
    b = np.arange(start=X[:,1].min()-1, stop=X[:,0].max()+1,step=100)
    XX,YY = np.meshgrid(a,b)
    input_array = np.array([XX.ravel(),YY.ravel()]).T
    labels = clf.predict(input_array)
    plt.contourf(XX,YY,labels.reshape(XX.shape),alpha=0.5)
    plt.scatter(X[:0],X[:1],c=y)

# %%
analyzer(max_depth=None)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 analyzer(max_depth=None)
#
# Cell In[3], line 10, in analyzer(max_depth)
#       8 XX,YY = np.meshgrid(a,b)
#       9 input_array = np.array([XX.ravel(),YY.ravel()]).T
# ---> 10 labels = clf.predict(input_array)
#      11 plt.contourf(XX,YY,labels.reshape(XX.shape),alpha=0.5)
#      12 plt.scatter(X[:0],X[:1],c=y)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/tree/_classes.py:528, in BaseDecisionTree.predict(self, X, check_input)
#     505 def predict(self, X, check_input=True):
#     506     """Predict class or regression value for X.
#     507
#     508     For a classification model, the predicted class for each sample in X is
#    (...)
#     526         The predicted classes, or the predict values.
#     527     """
# --> 528     check_is_fitted(self)
#     529     X = self._validate_X_predict(X, check_input)
#     530     proba = self.tree_.predict(X)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:1622, in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1619     raise TypeError("%s is not an estimator instance." % (estimator))
#    1621 if not _is_fitted(estimator, attributes, all_or_any):
# -> 1622     raise NotFittedError(msg % {"name": type(estimator).__name__})
#
# NotFittedError: This DecisionTreeClassifier instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.
